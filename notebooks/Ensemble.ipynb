# %%
cd ..
# Out:
# D:\Kevin\Machine Learning\Cassava Leaf Disease Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from src.dataset import CassavaDataset
from src import config
from src.transforms import *

# %matplotlib inline

# %%
train_folds = pd.read_csv(config.TRAIN_FOLDS)
train = train_folds[train_folds.fold != 0]
train_loader = CassavaDataset(train, data_root=config.TRAIN_IMAGES_DIR, transforms=get_train_transforms(), output_label=True)

# %%
image, label = train_loader[5]

# %%
plt.imshow(image.permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
label
# Out:
# array([0.        , 0.        , 0.77140808, 0.22859192, 0.        ])
